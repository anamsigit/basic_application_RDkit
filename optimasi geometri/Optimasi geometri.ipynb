# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem.Draw.MolDrawing import MolDrawing, DrawingOptions
from rdkit.Chem import Draw
from rdkit.Chem import PyMol

ibu = Chem.MolFromSmiles('CC(C)Cc1ccc(cc1)C(C)C(=O)O')
ibuH = Chem.AddHs(ibu)
AllChem.EmbedMolecule(ibuH)
v = PyMol.MolViewer()
v.ShowMol(ibuH)
v.server.do('ray')
v.GetPNG()
AllChem.MMFFOptimizeMolecule(ibuH)
v.ShowMol(ibuH,name='optimized',showOnly=True);
v.server.do('ray')
v.GetPNG()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Input In [2], in <cell line: 11>()
#       9 ibuH = Chem.AddHs(ibu)
#      10 AllChem.EmbedMolecule(ibuH)
# ---> 11 v = PyMol.MolViewer()
#      12 v.ShowMol(ibuH)
#      13 v.server.do('ray')
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\rdkit\Chem\PyMol.py:37, in MolViewer.__init__(self, host, port, force, **kwargs)
#      35 _server = None
#      36 serv = Server('http://%s:%d' % (host, port))
# ---> 37 serv.ping()
#      38 _server = serv
#      39 self.server = serv
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\xmlrpc\client.py:1116, in _Method.__call__(self, *args)
#    1115 def __call__(self, *args):
# -> 1116     return self.__send(self.__name, args)
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\xmlrpc\client.py:1458, in ServerProxy.__request(self, methodname, params)
#    1452 def __request(self, methodname, params):
#    1453     # call a method on the remote server
#    1455     request = dumps(params, methodname, encoding=self.__encoding,
#    1456                     allow_none=self.__allow_none).encode(self.__encoding, 'xmlcharrefreplace')
# -> 1458     response = self.__transport.request(
#    1459         self.__host,
#    1460         self.__handler,
#    1461         request,
#    1462         verbose=self.__verbose
#    1463         )
#    1465     if len(response) == 1:
#    1466         response = response[0]
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\xmlrpc\client.py:1160, in Transport.request(self, host, handler, request_body, verbose)
#    1158 for i in (0, 1):
#    1159     try:
# -> 1160         return self.single_request(host, handler, request_body, verbose)
#    1161     except http.client.RemoteDisconnected:
#    1162         if i:
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\xmlrpc\client.py:1172, in Transport.single_request(self, host, handler, request_body, verbose)
#    1169 def single_request(self, host, handler, request_body, verbose=False):
#    1170     # issue XML-RPC request
#    1171     try:
# -> 1172         http_conn = self.send_request(host, handler, request_body, verbose)
#    1173         resp = http_conn.getresponse()
#    1174         if resp.status == 200:
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\xmlrpc\client.py:1285, in Transport.send_request(self, host, handler, request_body, debug)
#    1283 headers.append(("User-Agent", self.user_agent))
#    1284 self.send_headers(connection, headers)
# -> 1285 self.send_content(connection, request_body)
#    1286 return connection
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\xmlrpc\client.py:1315, in Transport.send_content(self, connection, request_body)
#    1312     request_body = gzip_encode(request_body)
#    1314 connection.putheader("Content-Length", str(len(request_body)))
# -> 1315 connection.endheaders(request_body)
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\http\client.py:1248, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1246 else:
#    1247     raise CannotSendHeader()
# -> 1248 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\http\client.py:1008, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1006 msg = b"\r\n".join(self._buffer)
#    1007 del self._buffer[:]
# -> 1008 self.send(msg)
#    1010 if message_body is not None:
#    1011
#    1012     # create a consistent interface to message_body
#    1013     if hasattr(message_body, 'read'):
#    1014         # Let file-like take precedence over byte-like.  This
#    1015         # is needed to allow the current position of mmap'ed
#    1016         # files to be taken into account.
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\http\client.py:948, in HTTPConnection.send(self, data)
#     946 if self.sock is None:
#     947     if self.auto_open:
# --> 948         self.connect()
#     949     else:
#     950         raise NotConnected()
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\http\client.py:919, in HTTPConnection.connect(self)
#     917 def connect(self):
#     918     """Connect to the host and port specified in __init__."""
# --> 919     self.sock = self._create_connection(
#     920         (self.host,self.port), self.timeout, self.source_address)
#     921     self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     923     if self._tunnel_host:
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\socket.py:843, in create_connection(address, timeout, source_address)
#     841 if err is not None:
#     842     try:
# --> 843         raise err
#     844     finally:
#     845         # Break explicitly a reference cycle
#     846         err = None
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\socket.py:831, in create_connection(address, timeout, source_address)
#     829 if source_address:
#     830     sock.bind(source_address)
# --> 831 sock.connect(sa)
#     832 # Break explicitly a reference cycle
#     833 err = None
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
